# %% [markdown]
# #Table 1: Debate Arguments

# %%
debate <- data.frame(
    Argument_ID = c("A001", "A002", "A003", "A004", "A005", "A006"),
    Position = c("For", "For", "For", "Against", "Against", "Against"),
    Topic = c("Learning", "Productivity", "AI Literacy", "Academic Integrity", "Dependency", "Assessment"),
    Claim = c("AI can provide students with immediate learning support.",
              "AI can help student complete routine academic tasks more efficiently.",
              "Allowing AI use can help students develop AI literacy.",
              "Undisclosed AI-generated work may create academic integrity concerns.",
              "Excessive AI use may reduce students' independent problem-solving practice.",
              "AI use may mmake it more difficult to determin whether submitted work reflects student learning.")

)

debate
# Out:
#   Argument_ID Position Topic
# 1 A001        For      Learning
# 2 A002        For      Productivity
# 3 A003        For      AI Literacy
# 4 A004        Against  Academic Integrity
# 5 A005        Against  Dependency
# 6 A006        Against  Assessment
#   Claim
# 1 AI can provide students with immediate learning support.
# 2 AI can help student complete routine academic tasks more efficiently.
# 3 Allowing AI use can help students develop AI literacy.
# 4 Undisclosed AI-generated work may create academic integrity concerns.
# 5 Excessive AI use may reduce students' independent problem-solving practice.
# 6 AI use may mmake it more difficult to determin whether submitted work reflects student learning.

# %% [markdown]
# #Table 2: Evidence

# %%
evidence <- data.frame (
  Evidence_ID = c("E001", "E002", "E003", "E004", "E005", "E006"),
  Argument_ID = c("A001", "A002", "A003", "A004", "A005", "A006"),
  Evidence_Type = c("Research", "Research", "Policy", "Policy", "Research", "Research"),
  Strength = c("Strong", "Moderate", "Strong", "Strong", "Moderate", "Strong")
)
print(evidence)
# Out:
#   Evidence_ID Argument_ID Evidence_Type Strength
# 1        E001        A001      Research   Strong
# 2        E002        A002      Research Moderate
# 3        E003        A003        Policy   Strong
# 4        E004        A004        Policy   Strong
# 5        E005        A005      Research Moderate
# 6        E006        A006      Research   Strong

# %% [markdown]
# #2. Count Arguments

# %%
table(debate$Position)
# Out:
# Against     For
#       3       3

# %%
nrow(debate)
# Out:
# [1] 6

# %%
table(evidence$Strength)
# Out:
# Moderate   Strong
#        2        4

# %%
nrow(evidence)
# Out:
# [1] 6

# %% [markdown]
# #3. Connect Table Arguments and Evidence

# %%
knowledge_base <- merge(
  debate,
  evidence,
  by = "Argument_ID"
)

print(knowledge_base)
# Out:
#   Argument_ID Position              Topic
# 1        A001      For           Learning
# 2        A002      For       Productivity
# 3        A003      For        AI Literacy
# 4        A004  Against Academic Integrity
# 5        A005  Against         Dependency
# 6        A006  Against         Assessment
#                                                                                              Claim
# 1                                         AI can provide students with immediate learning support.
# 2                            AI can help student complete routine academic tasks more efficiently.
# 3                                           Allowing AI use can help students develop AI literacy.
# 4                            Undisclosed AI-generated work may create academic integrity concerns.
# 5                      Excessive AI use may reduce students' independent problem-solving practice.
# ...

# %% [markdown]
# #4. Convert Evidence Strength into a Score

# %%
get_score <- function(strength){
  if (strength == "Strong"){
    return(3)
   } else if (strength == "Moderate"){
    return(2)
   } else if (strength == "Weak"){
    Return(1)
   } else{
    return(0)
   }
}

get_score("Moderate")
# Out:
# [1] 2

# %% [markdown]
# #5. Add Evidence Score

# %%
knowledge_base$Evidence_Score <- sapply(
  knowledge_base$Strength,
  get_score
)

print(knowledge_base)
# Out:
#   Argument_ID Position              Topic
# 1        A001      For           Learning
# 2        A002      For       Productivity
# 3        A003      For        AI Literacy
# 4        A004  Against Academic Integrity
# 5        A005  Against         Dependency
# 6        A006  Against         Assessment
#                                                                                              Claim
# 1                                         AI can provide students with immediate learning support.
# 2                            AI can help student complete routine academic tasks more efficiently.
# 3                                           Allowing AI use can help students develop AI literacy.
# 4                            Undisclosed AI-generated work may create academic integrity concerns.
# 5                      Excessive AI use may reduce students' independent problem-solving practice.
# ...

# %% [markdown]
# #6. Convert Evidence Score to Support

# %%
Classify_support <- function(score){

  if(score == 3){
    return("Strongly Supported")
  } else if(score == 2){
    return("Moderately Supported")
  } else if(score == 1){
    return("Weakly Supported")
  } else {
    return("No Support")
  }
}

Classify_support(3)
# Out:
# [1] "Strongly Supported"

# %% [markdown]
# #7. Add Evidence Support

# %%
knowledge_base$Support_Level <- sapply(
  knowledge_base$Evidence_Score,
  Classify_support
)

print(knowledge_base)
# Out:
#   Argument_ID Position              Topic
# 1        A001      For           Learning
# 2        A002      For       Productivity
# 3        A003      For        AI Literacy
# 4        A004  Against Academic Integrity
# 5        A005  Against         Dependency
# 6        A006  Against         Assessment
#                                                                                              Claim
# 1                                         AI can provide students with immediate learning support.
# 2                            AI can help student complete routine academic tasks more efficiently.
# 3                                           Allowing AI use can help students develop AI literacy.
# 4                            Undisclosed AI-generated work may create academic integrity concerns.
# 5                      Excessive AI use may reduce students' independent problem-solving practice.
# ...

# %% [markdown]
# #8. Search by Topic

# %%
search_topic <- function(topic){

  result <- subset(
    knowledge_base,
    Topic == topic
  )
  if(nrow(result) == 0){
    cat("Topic not found")
  } else{
    print(result)
  }
}

# %%
search_topic("Learning")
# Out:
#   Argument_ID Position    Topic
# 1        A001      For Learning
#                                                      Claim Evidence_ID
# 1 AI can provide students with immediate learning support.        E001
#   Evidence_Type Strength Evidence_Score      Support_Level
# 1      Research   Strong              3 Strongly Supported

# %% [markdown]
# #9. Challenge

# %% [markdown]
# ### Add New Arguments

# %%
new_debate_arguments <- data.frame(
  Argument_ID = c("A007", "A008", "A009", "A010", "A011", "A012", "A013", "A014", "A015"),
  Position = c("For", "Against", "For", "Against", "For", "Against", "For", "Against", "For"),
  Topic = c("Creativity", "Data Privacy", "Personalization", "Cost", "Efficiency", "Bias", "Engagement", "Ethical Concerns", "Accessibility"),
  Claim = c(
    "AI tools can enhance student creativity by providing new perspectives and rapid prototyping.",
    "AI tools raise concerns about student data privacy and security.",
    "AI can personalize learning experiences for individual students.",
    "Implementing AI solutions can be expensive for educational institutions.",
    "AI can automate grading and feedback, increasing instructor efficiency.",
    "AI algorithms may perpetuate existing biases in educational content.",
    "AI-powered interactive tools can increase student engagement.",
    "Over-reliance on AI can lead to ethical dilemmas and reduced human interaction.",
    "AI tools can improve accessibility for students with disabilities."  )
)

debate <- rbind(debate, new_debate_arguments)
debate <- unique(debate)

print(debate)
# Out:
#    Argument_ID Position              Topic
# 1         A001      For           Learning
# 2         A002      For       Productivity
# 3         A003      For        AI Literacy
# 4         A004  Against Academic Integrity
# 5         A005  Against         Dependency
# 6         A006  Against         Assessment
# 7         A007      For         Creativity
# 9         A008  Against       Data Privacy
# 10        A009      For    Personalization
# 11        A010  Against               Cost
# 12        A011      For         Efficiency
# 13        A012  Against               Bias
# 14        A013      For         Engagement
# 15        A014  Against   Ethical Concerns
# 16        A015      For      Accessibility
#                                                                                               Claim
# 1                                          AI can provide students with immediate learning support.
# ...

# %%
new_evidence <- data.frame(
  Evidence_ID = c("E007", "E008", "E009", "E010", "E011", "E012", "E013", "E014", "E015"),
  Argument_ID = c("A007", "A008", "A009", "A010", "A011", "A012", "A013", "A014", "A015"),
  Evidence_Type = c("Research", "Policy", "Research", "Research", "Policy", "Research", "Research", "Policy", "Research"),
  Strength = c("Strong", "Moderate", "Strong", "Moderate", "Strong", "Strong", "Moderate", "Strong", "Strong")
)

evidence <- rbind(evidence, new_evidence)
evidence <- unique(evidence)

print(evidence)
# Out:
#    Evidence_ID Argument_ID Evidence_Type Strength
# 1         E001        A001      Research   Strong
# 2         E002        A002      Research Moderate
# 3         E003        A003        Policy   Strong
# 4         E004        A004        Policy   Strong
# 5         E005        A005      Research Moderate
# 6         E006        A006      Research   Strong
# 7         E007        A007      Research   Strong
# 9         E008        A008        Policy Moderate
# 10        E009        A009      Research   Strong
# 11        E010        A010      Research Moderate
# 12        E011        A011        Policy   Strong
# 13        E012        A012      Research   Strong
# 14        E013        A013      Research Moderate
# 15        E014        A014        Policy   Strong
# 16        E015        A015      Research   Strong

# %%
knowledge_base <- merge(
  debate,
  evidence,
  by = "Argument_ID"
)

print(knowledge_base)
# Out:
#    Argument_ID Position              Topic
# 1         A001      For           Learning
# 2         A002      For       Productivity
# 3         A003      For        AI Literacy
# 4         A004  Against Academic Integrity
# 5         A005  Against         Dependency
# 6         A006  Against         Assessment
# 7         A007      For         Creativity
# 8         A008  Against       Data Privacy
# 9         A009      For    Personalization
# 10        A010  Against               Cost
# 11        A011      For         Efficiency
# 12        A012  Against               Bias
# 13        A013      For         Engagement
# 14        A014  Against   Ethical Concerns
# 15        A015      For      Accessibility
#                                                                                               Claim
# 1                                          AI can provide students with immediate learning support.
# ...

# %%
knowledge_base$Evidence_Score <- sapply(
  knowledge_base$Strength,
  get_score
)

print(knowledge_base)
# Out:
#    Argument_ID Position              Topic
# 1         A001      For           Learning
# 2         A002      For       Productivity
# 3         A003      For        AI Literacy
# 4         A004  Against Academic Integrity
# 5         A005  Against         Dependency
# 6         A006  Against         Assessment
# 7         A007      For         Creativity
# 8         A008  Against       Data Privacy
# 9         A009      For    Personalization
# 10        A010  Against               Cost
# 11        A011      For         Efficiency
# 12        A012  Against               Bias
# 13        A013      For         Engagement
# 14        A014  Against   Ethical Concerns
# 15        A015      For      Accessibility
#                                                                                               Claim
# 1                                          AI can provide students with immediate learning support.
# ...

# %%
knowledge_base$Support_Level <- sapply(
  knowledge_base$Evidence_Score,
  Classify_support
)

print(knowledge_base)
# Out:
#    Argument_ID Position              Topic
# 1         A001      For           Learning
# 2         A002      For       Productivity
# 3         A003      For        AI Literacy
# 4         A004  Against Academic Integrity
# 5         A005  Against         Dependency
# 6         A006  Against         Assessment
# 7         A007      For         Creativity
# 8         A008  Against       Data Privacy
# 9         A009      For    Personalization
# 10        A010  Against               Cost
# 11        A011      For         Efficiency
# 12        A012  Against               Bias
# 13        A013      For         Engagement
# 14        A014  Against   Ethical Concerns
# 15        A015      For      Accessibility
#                                                                                               Claim
# 1                                          AI can provide students with immediate learning support.
# ...

# %%
table(evidence$Strength)
# Out:
# Moderate   Strong
#        5       10

# %%
search_topic("Creativity")
# Out:
#   Argument_ID Position      Topic
# 7        A007      For Creativity
#                                                                                          Claim
# 7 AI tools can enhance student creativity by providing new perspectives and rapid prototyping.
#   Evidence_ID Evidence_Type Strength Evidence_Score      Support_Level
# 7        E007      Research   Strong              3 Strongly Supported

# %%
search_topic("Data Privacy")
# Out:
#   Argument_ID Position        Topic
# 8        A008  Against Data Privacy
#                                                              Claim Evidence_ID
# 8 AI tools raise concerns about student data privacy and security.        E008
#   Evidence_Type Strength Evidence_Score        Support_Level
# 8        Policy Moderate              2 Moderately Supported

# %%
search_topic("Cost")
# Out:
#    Argument_ID Position Topic
# 10        A010  Against  Cost
#                                                                       Claim
# 10 Implementing AI solutions can be expensive for educational institutions.
#    Evidence_ID Evidence_Type Strength Evidence_Score        Support_Level
# 10        E010      Research Moderate              2 Moderately Supported

# %%
library(ggplot2)

strength_counts <- as.data.frame(table(knowledge_base$Strength))
colnames(strength_counts) <- c("Strength", "Count")

strength_plot <- ggplot(strength_counts, aes(x = Strength, y = Count, fill = Strength)) +
  geom_bar(stat = "identity") +
  labs(title = "Distribution of Evidence Strength",
       x = "Strength Level",
       y = "Number of Arguments") +
  theme_minimal() +
  theme(legend.position = "none")

print(strength_plot)

# %%
argument_position_counts <- as.data.frame(table(debate$Position))
colnames(argument_position_counts) <- c("Position", "Count")
print(argument_position_counts)
# Out:
#   Position Count
# 1  Against     7
# 2      For     8

# %%
evidence_summary <- knowledge_base %>%
  group_by(Support_Level) %>%
  summarise(Count = n()) %>%
  arrange(desc(Count))

print(evidence_summary)
# Out:
# Error in knowledge_base %>% group_by(Support_Level) %>% summarise(Count = n()) %>% : could not find function "%>%"
# Traceback:

# %%
print(knowledge_base)
# Out:
#    Argument_ID Position              Topic
# 1         A001      For           Learning
# 2         A002      For       Productivity
# 3         A003      For        AI Literacy
# 4         A004  Against Academic Integrity
# 5         A005  Against         Dependency
# 6         A006  Against         Assessment
# 7         A007      For         Creativity
# 8         A008  Against       Data Privacy
# 9         A009      For    Personalization
# 10        A010  Against               Cost
# 11        A011      For         Efficiency
# 12        A012  Against               Bias
# 13        A013      For         Engagement
# 14        A014  Against   Ethical Concerns
# 15        A015      For      Accessibility
#                                                                                               Claim
# 1                                          AI can provide students with immediate learning support.
# ...
